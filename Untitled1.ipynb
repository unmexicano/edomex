# %%
# %matplotlib inline

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pysal as ps
import geopandas as gpd
from sklearn import cluster
from sklearn.preprocessing import scale

sns.set(style="whitegrid")
# Out:
# C:\Users\Angel ONC\Anaconda3\lib\site-packages\pysal\model\spvcm\abstracts.py:10: UserWarning: The `dill` module is required to use the sqlite backend fully.
#   from .sqlite import head_to_sql, start_sql

# %%
zc_link = 'edomex.geojson'

# %%
zc = gpd.read_file(zc_link)
zc.plot(color='red')

# %%
lst = pd.read_csv('regiones k-means.csv', engine = 'python')

# %%
lst
# Out:
#      CVEGEO  CVE_ENT  CVE_MUN                       NOMGEO  _pop2018  \
# 0     15013       15       13         Atizapán de Zaragoza    555364
# 1     15062       15       62                    Ocoyoacac     73207
# 2     15055       15       55                Mexicaltzingo     14053
# 3     15065       15       65                       Otumba     40556
# 4     15064       15       64                       El Oro     12270
# 5     15122       15      122  Valle de Chalco Solidaridad    413892
# 6     15068       15       68                       Ozumba     32120
# 7     15020       15       20      Coacalco de Berriozábal    304640
# 8     15034       15       34                    Ecatzingo     11095
# 9     15120       15      120                     Zumpango    198245
# 10    15094       15       94                   Tepetlixpa     21125
# 11    15080       15       80                     Sultepec     28599
# 12    15119       15      119                  Zumpahuacán     18148
# ...

# %%
rt_av = lst.groupby('CVEGEO')['POP2019']\
           .mean()\
           .rename(lambda x: str(int(x)))

# %%
zrt = zc[['geometry', 'CVEGEO']].join(rt_av, on='CVEGEO')\
                                 .dropna()
zrt.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 125 entries, 0 to 124
# Data columns (total 3 columns):
# geometry    125 non-null object
# CVEGEO      125 non-null object
# POP2019     125 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 3.9+ KB

# %%
zrt.to_file('tmp')
w = ps.queen_from_shapefile('tmp.shp', idVariable='CVEGEO')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-ac1ee594d714> in <module>
#       1 zrt.to_file('tmp')
# ----> 2 w = ps.queen_from_shapefile('tmp.shp', idVariable='CVEGEO')
#
# AttributeError: module 'pysal' has no attribute 'queen_from_shapefile'
